# %% [markdown]
# # 数据可视化

# %%
import pandas as pd
import numpy as np
import os
# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体设置-黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题
sns.set(font='SimHei')  # 解决Seaborn中文显示问题

# %%
# Load data
df_train = pd.read_csv('../dataset/600031.csv')
# Show first lines of data
df_train.head()
# Out:
#            日期     开盘     收盘     最高     最低      成交量         成交额    振幅   涨跌幅  \
# 0  2020-11-09  27.80  27.54  28.14  26.89   856249  2348800992  4.55  0.18
# 1  2020-11-10  27.98  27.32  27.98  26.91   558824  1523209504  3.89 -0.80
# 2  2020-11-11  27.33  28.31  28.86  27.21  1015374  2873205488  6.04  3.62
# 3  2020-11-12  28.31  28.70  28.88  27.91   718595  2041558432  3.43  1.38
# 4  2020-11-13  28.28  28.16  28.50  27.60   674807  1888773520  3.14 -1.88
#
#     涨跌额   换手率
# 0  0.05  1.01
# 1 -0.22  0.66
# 2  0.99  1.20
# 3  0.39  0.85
# 4 -0.54  0.80

# %%
# 数据预处理

# %%
df_train.set_index('日期',inplace=True)

# %%
df_train.head()
# Out:
#                开盘     收盘     最高     最低      成交量         成交额    振幅   涨跌幅   涨跌额  \
# 日期
# 2020-11-09  27.80  27.54  28.14  26.89   856249  2348800992  4.55  0.18  0.05
# 2020-11-10  27.98  27.32  27.98  26.91   558824  1523209504  3.89 -0.80 -0.22
# 2020-11-11  27.33  28.31  28.86  27.21  1015374  2873205488  6.04  3.62  0.99
# 2020-11-12  28.31  28.70  28.88  27.91   718595  2041558432  3.43  1.38  0.39
# 2020-11-13  28.28  28.16  28.50  27.60   674807  1888773520  3.14 -1.88 -0.54
#
#              换手率
# 日期
# 2020-11-09  1.01
# 2020-11-10  0.66
# 2020-11-11  1.20
# 2020-11-12  0.85
# 2020-11-13  0.80

# %%
datalist = list()
for i in range(0, len(df_train)):
    if df_train.iloc[i, list(df_train.columns).index('涨跌幅')] > 0:
        datalist.append(1)
    else:
        datalist.append(0)
df_train['是否涨跌'] = datalist

# %% [markdown]
# Seaborn library 是一个流行作图工具。这里以它为例作图，直观地分析数据中的每个特征值和目标（survived）关系。

# %% [markdown]
# # 下面的函数用于调整图形中文本信息的尺寸和位置。

# %%
# Function of drawing graph;
def draw(graph):
    for p in graph.patches:
        height = p.get_height()
        graph.text(p.get_x()+p.get_width()/2., height + 5,height ,ha= "center")

# %% [markdown]
# * 第一种方式
#     x: x轴上的条形图，以x标签划分统计个数
#
#     y: y轴上的条形图，以y标签划分统计个数
#
#     hue: 在x或y标签划分的同时，再以hue标签划分统计个数
# * 第二种方式
#     x: x轴上的条形图，直接为series数据
#
#     y: y轴上的条形图，直接为series数据
#
#     sns.countplot(x=df_train['是否涨跌'])
#
# data: DataFrame或array或array列表，用于绘图的数据集，x或y缺失时，data参数为数据集，同时x或y不可缺少，必须要有其中一个。
#
# order, hue_order分别是对x或y的字段排序，hue的字段排序。排序的方式为列表。
# order=['Third', 'Second', 'First']

# %%
# Draw rise vs. non-rise;
sns.set(style="darkgrid")

plt.figure(figsize = (8, 5))
graph= sns.countplot(x='是否涨跌', hue="是否涨跌", data=df_train)

draw(graph)
# Out:
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26159 (\N{CJK UNIFIED IDEOGRAPH-662F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21542 (\N{CJK UNIFIED IDEOGRAPH-5426}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 28072 (\N{CJK UNIFIED IDEOGRAPH-6DA8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36300 (\N{CJK UNIFIED IDEOGRAPH-8DCC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# # **Line Plot**

# %% [markdown]
# 线图中x轴式序号，y轴有两列数据：涨跌幅, 换手率.

# %%
plt.figure(figsize=(14,6))

plt.title("Line Plot of '涨跌幅' and '换手率'")

graph = sns.lineplot(data=df_train[['涨跌幅', '换手率']])
# Out:
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 28072 (\N{CJK UNIFIED IDEOGRAPH-6DA8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36300 (\N{CJK UNIFIED IDEOGRAPH-8DCC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24133 (\N{CJK UNIFIED IDEOGRAPH-5E45}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25442 (\N{CJK UNIFIED IDEOGRAPH-6362}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25163 (\N{CJK UNIFIED IDEOGRAPH-624B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(14,6))

plt.title("Scatter Plot of 换手率")

graph = sns.scatterplot(x=df_train['换手率'], y=df_train['是否涨跌'])
# Out:
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25442 (\N{CJK UNIFIED IDEOGRAPH-6362}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25163 (\N{CJK UNIFIED IDEOGRAPH-624B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26159 (\N{CJK UNIFIED IDEOGRAPH-662F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21542 (\N{CJK UNIFIED IDEOGRAPH-5426}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 28072 (\N{CJK UNIFIED IDEOGRAPH-6DA8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36300 (\N{CJK UNIFIED IDEOGRAPH-8DCC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # **Histogram**

# %% [markdown]
# 直方图描述 成交量 的分布规律

# %%
plt.figure(figsize=(14,6))

plt.title("Histogram of '成交量'")

graph = sns.distplot(a=df_train['成交量'], kde=False)
# Out:
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25104 (\N{CJK UNIFIED IDEOGRAPH-6210}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20132 (\N{CJK UNIFIED IDEOGRAPH-4EA4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(14,6))

plt.title("Histogram of '成交量'")

graph = sns.kdeplot(data=df_train['成交量'], shade=True)
# Out:
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25104 (\N{CJK UNIFIED IDEOGRAPH-6210}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20132 (\N{CJK UNIFIED IDEOGRAPH-4EA4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # **Bar Chat**

# %% [markdown]
# 条形图描述成交量的变化规律。

# %%
plt.figure(figsize=(14,6))

plt.title("BarChart of '成交量'")

graph = sns.barplot(x=df_train.index, y=df_train['成交量'])
# Out:
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25104 (\N{CJK UNIFIED IDEOGRAPH-6210}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20132 (\N{CJK UNIFIED IDEOGRAPH-4EA4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # **Heat Map**

# %% [markdown]
# 热图用颜色描述 成交量 的数值变化。

# %%
plt.figure(figsize=(14,6))

plt.title("Heatmap of 成交量")

graph = sns.heatmap(data=df_train[['成交量']], annot=True)
# Out:
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/seaborn/utils.py:95: UserWarning: Glyph 25104 (\N{CJK UNIFIED IDEOGRAPH-6210}) missing from current font.
#   fig.canvas.draw()
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/seaborn/utils.py:95: UserWarning: Glyph 20132 (\N{CJK UNIFIED IDEOGRAPH-4EA4}) missing from current font.
#   fig.canvas.draw()
# /home/lin/anaconda3/envs/deep/lib/python3.8/site-packages/seaborn/utils.py:95: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from current font.
#   fig.canvas.draw()
